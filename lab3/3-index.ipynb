# %% [markdown]
# [index](../index.ipynb)

# %% [markdown]
# - [3.1-concepts.ipynb](3.1-concepts.ipynb)
# - [3.2-codes.ipynb](3.2-codes.ipynb)
#   - [Task-1](3.2-codes.ipynb)
#   - [Task-2](3.2-codes.ipynb)
#
#
# ### # misc
# - [URL links to any cell in a notebook with a copy link button you can hover on to copy it #5156](https://github.com/sagemathinc/cocalc/issues/5156)
