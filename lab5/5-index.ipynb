# %% [markdown]
# - [5.1-tasks.ipynb](5.1-tasks.ipynb)
# - [5.2-concepts.ipynb](5.2-concepts.ipynb)
# - [5.2-ml-inPython.ipynb](5.2-ml-inPython.ipynb)

# %% [markdown]
# Topics to learn in this lab
# - BFS
# - DFS
#
#
# things to know to do in python
# - writing functions
