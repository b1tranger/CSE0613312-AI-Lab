# %% [markdown]
# Go to index: [link](2-Lab_1.ipynb)

# %% [markdown]
# ### # (unorganized concepts)
# - "mutable" and "immutable" objects: [file](2.1.1-mutable-immutable.ipynb)

# %% [markdown]
# ---

# %% [markdown]
# <h1 align=center># Data Structures in Python</h1>

# %% [markdown]
# ---

# %% [markdown]
# ### # List
# - we use [ ] to define lists
# - we can use type( ) function to determine the list's data type
# - len( ) function
# - mutable (unlike "tuple")
# - can put multiple file types in a single list
# ### # Dictionary
# ```
# dict={"name_1":10,"name_2":29}
# ```
# ### # Set
# - collection of unique data

# %% [markdown]
# ---

# %% [markdown]
# <h1 align=center># Libraries in Python</h1>

# %% [markdown]
# ---
