# %% [markdown]
# | Lab |  Topics+Files|
# |-|-|
# | [1-index.ipynb](lab1/1-index.ipynb) | Introduction |
# | [2-index.ipynb](lab2/2-index.ipynb) | Data Structures and Libraries in python |
# | [3-index.ipynb](lab3/3-index.ipynb) | Conditions, Loops, Functions |
# | [5-index.ipynb](lab5/5-index.ipynb) | Function, BFS, DFS |
# | [6-index.ipynb](lab6/6-index.ipynb) | BFS, DFS |
#
#
# <!-- <a href=""><a> -->
# <!-- <table>
# <thead>
# <tr>
# <th>Lab</th><th>Topics+Files</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><a href="1-introduction.ipynb">1. Introduction<a></td>
# <td><a href=""><a></td>
# </tr>
# <tr>
# <td><a href="2-Lab_1.ipynb">2. Lab 1<a></td>
# <td><a href=""><a></td>
# </tr>
# </tbody>
# </table> -->
