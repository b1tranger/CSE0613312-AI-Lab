# %% [markdown]
# | Lab |  Topics+Files|
# |-|-|
# | [1. Introduction](1-introduction.ipynb) |  |
# | [2. Lab 1](2-Lab_1.ipynb) | |
#
#
# <!-- <a href=""><a> -->
# <!-- <table>
# <thead>
# <tr>
# <th>Lab</th><th>Topics+Files</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><a href="1-introduction.ipynb">1. Introduction<a></td>
# <td><a href=""><a></td>
# </tr>
# <tr>
# <td><a href="2-Lab_1.ipynb">2. Lab 1<a></td>
# <td><a href=""><a></td>
# </tr>
# </tbody>
# </table> -->
