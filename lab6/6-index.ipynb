# %% [markdown]
# [index](../index.ipynb)

# %% [markdown]
# - [6.1-concepts.ipynb](6.1-concepts.ipynb)
# - [6.2-tasks.ipynb](6.2-tasks.ipynb)

# %% [markdown]
# Additional Courses
# - https://www.3blue1brown.com/
# - https://inst.eecs.berkeley.edu/~cs188/sp25/
