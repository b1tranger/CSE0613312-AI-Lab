# %% [markdown]
# [previous](6-AI-Lab.ipynb)

# %% [markdown]
# <hr>
#
# #### # Task-1: Define Function (incomplete)

# %%
def func_1(rec):
    print(f"Called function; passed value {rec}")


func_1(1)
# Out:
# Called function; passed value 1

# %% [markdown]
# <hr>
#
# #### # Task-2: DFS Algorithm
#
# https://www.geeksforgeeks.org/dsa/depth-first-search-or-dfs-for-a-graph/

# %%
### DFS Functions



def inGraph(adj,u,v): # adding values to the graph stack
    adj[u].append(v)
    adj[v].append(u)

### Main Function

v = 5
adj = []

for i in range(v): # creating space for List?
    adj.append([])

inGraph(adj,1,2)
inGraph(adj,1,0)
inGraph(adj,2,0)
inGraph(adj,2,3)
inGraph(adj,2,4)

res = dfs(adj) # calling dfs function to run the graph traversal


###
