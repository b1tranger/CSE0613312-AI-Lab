# %% [markdown]
# [index](../index.ipynb)

# %% [markdown]
# ### # we will learn
# - python data structures
# - numpy
# - pandas
# - mathplotlib
# - AI algorithms:
#   - informed search: Best First Search, A* Search
#   - uninformed search: BFS, DFS, Depth Limited Search
#   - adversarial search: min-max, alpha-beta search
#
# ### # python concepts:
# - identation
# - variable declaration
# - multiple variable assigning
#
# ### # Codes
# - [1.1-lab-1.ipynb](1.1-lab-1.ipynb)
#
# ### # Course Outline:
# - [PDF](1.4-AI-Lab-Manual-CSE54.pdf)
#
# ### # troubleshooting:
# - Manik: "To run in IDE we need to use `"C:\Users\Student\AppData\Local\Programs\Python\Python313\pythonw.exe"`
# instead of
# `"C:\Users\Student\AppData\Local\Programs\Python\Python313\python.exe"` "
#
#
# ### # sources (personal):
#   - [libraries-in-python](https://www.geeksforgeeks.org/python/libraries-in-python/) | [PDF](1.2-libraries_in_python.pdf)
#   - [artificial-intelligence/adversarial-search-algorithms](https://www.geeksforgeeks.org/artificial-intelligence/adversarial-search-algorithms/) | [PDF](1.3-adversarial_search+algorithms.pdf)
