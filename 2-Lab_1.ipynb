# %% [markdown]
# [index](index.ipynb)

# %% [markdown]
# ### # theory
# - [2.1-concepts](2.1-concepts.ipynb)
#
# ### # tasks
# - [Lab-1-codes](2.2-Lab-1-codes.ipynb)
#
# ### # resources
# - Extension: [copy-as-markdown](https://chromewebstore.google.com/detail/copy-as-markdown/fkeaekngjflipcockcnpobkpbbfbhmdn?hl=en)
# - Suggested: https://www.w3schools.com/python/
